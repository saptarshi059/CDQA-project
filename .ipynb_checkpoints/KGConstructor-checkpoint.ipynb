# %%
#Run this cell once to install pykg2vec
# !git clone https://github.com/Sujit-O/pykg2vec.git
# %cd pykg2vec/
# !python setup.py install

# %%
#Generate tuples (Question, Token, SemType)
# %cd ~/Desktop/covid-project

import pandas as pd
s = pd.read_json('sample.json')

documents = s.iloc[0][0]['Document']['Utterances']
Metamap_Tokenizations = [] #To be used for final QA

def retrieve_tokens(SyntaxUnits):
    tokens = []
    for i in range(len(SyntaxUnits)):
        tokens.append(SyntaxUnits[i]['InputMatch'])
    return tokens

def retrieve_mappings(Mappings):
    mapped_semantic_types = []
    #No mappings found
    if len(Mappings) == 0:
        return [] #These words will get their embeddings from BERT
    else:
        candidates = Mappings[0]['MappingCandidates'] #Choosing Only top mappings
        for cnd in candidates:
            mapped_semantic_types.append([' '.join(cnd['MatchedWords']),cnd['SemTypes'][0]])
    return mapped_semantic_types
    
for doc in documents:
    Phrases = doc['Phrases']
    Phrase_Tokenizations = []
    Mappings = []
    for ph in Phrases:
        Phrase_Tokenizations.append(retrieve_tokens(ph['SyntaxUnits']))
        Mappings.append(retrieve_mappings(ph['Mappings']))
    #Flattening the Lists
    Phrase_Tokenizations = [item for sublist in Phrase_Tokenizations for item in sublist]
    Mappings = [item for sublist in Mappings for item in sublist]
    #Creating the final list
    Metamap_Tokenizations.append((doc['UttText'], Phrase_Tokenizations, Mappings))
# Out:
# /home/ubuntu/Desktop/covid-project

# %%
#Replacing each shorthand mapping with KG concept
import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="Saptarshi123!", database="umls")
mycursor = mydb.cursor()

for i in range(len(Metamap_Tokenizations)):
    for j in range(len(Metamap_Tokenizations[i][2])):
        mycursor.execute("select STY_RL from SRDEF where ABR = '%s' " % Metamap_Tokenizations[i][2][j][1])
        Metamap_Tokenizations[i][2][j][1] = mycursor.fetchall()[0][0]

mycursor.close()
# Out:
# True

# %%
#Generating the KG triples (KGT)
from itertools import permutations
from tqdm.notebook import tqdm

All_Mappings = [y for x in Metamap_Tokenizations for y in x[2]]
All_Concept_Pairs = permutations(All_Mappings, 2)

mydb = mysql.connector.connect(host="localhost", user="root", password="Saptarshi123!", database="umls")
mycursor = mydb.cursor()

KGT = set()

for term_pair in tqdm(All_Concept_Pairs):
    semantic_type1 = term_pair[0][1]
    semantic_type2 = term_pair[1][1]
    mycursor.execute("select RL from SRSTR where STY_RL1 = '%s' and STY_RL2 = '%s' " % (semantic_type1, semantic_type2))
    relation = mycursor.fetchall()
    if relation != []:
        KGT.add((semantic_type1, relation[0][0], semantic_type2))

mycursor.close()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# True

# %%
#Creating Train/Validation/Test splits for training KGE's
import pandas as pd
import numpy as np
import os

#Converting set to pandas dataframe for easily split 
KGT = pd.DataFrame(KGT)

#Giving the KGT dataframe meaningful column names
KGT.rename(columns={0: "E1", 1: "Rel", 2: "E2"}, inplace=True)

KGT.loc[len(KGT.index)] = ['Age Group', 'isa', 'Group']


#80/10/10 split
train, validation, test = np.split(KGT.sample(frac=1, random_state=42), [int(.8*len(KGT)), int(.9*len(KGT))])

#Saving datasets as .txt files
dataset_path = os.path.abspath('UMLS_KG')
np.savetxt(os.path.join(dataset_path, 'UMLS_KG-train.txt'), train.values, delimiter="\t", fmt="%s")
np.savetxt(os.path.join(dataset_path, 'UMLS_KG-valid.txt'), validation.values, delimiter="\t", fmt="%s")
np.savetxt(os.path.join(dataset_path, 'UMLS_KG-test.txt'), test.values, delimiter="\t", fmt="%s")

# %%
#Run this cell to execute pykg2vec programs
# %cd ~/Desktop/covid-project/pykg2vec/scripts
# Out:
# /home/ubuntu/Desktop/covid-project/pykg2vec/scripts

# %%
#Tune KGE model
# !python pykg2vec_tune.py -mn DistMult -ds UMLS_KG -dsp ~/Desktop/covid-project/UMLS_KG \
-hpf ~/Desktop/covid-project/UMLS_KG/hyperparams.yaml

# %%
#Train KGE
# !python pykg2vec_train.py -mn DistMult -ds UMLS_KG -dsp ~/Desktop/covid-project/UMLS_KG \
-lr 0.01 -l1 True -k 768 -b 128 -l 1000 -mg 1.00 -opt "sgd" -s "bern" -ngr 1
# Out:
# 2021-05-24 20:50:51,891 - pykg2vec.config - INFO -
# ------------------Global Setting--------------------
#                   lmbda : 0.1
#              batch_size : 128
#                  margin : 1.0
#               optimizer : sgd
#                sampling : bern
#                neg_rate : 1
#                  epochs : 1000
#           learning_rate : 0.01
#             hidden_size : 768
#         ent_hidden_size : 50
#         rel_hidden_size : 50
#           hidden_size_1 : 10
#                 l1_flag : True
#                   alpha : 0.1
#            filter_sizes : [1, 2, 3]
#             num_filters : 50
#     feature_map_dropout : 0.2
#           input_dropout : 0.3
#          hidden_dropout : 0.3
#         hidden_dropout1 : 0.4
#         hidden_dropout2 : 0.5
#         label_smoothing : 0.1
#                    cmax : 0.05
#                    cmin : 5.0
#     feature_permutation : 1
#          reshape_height : 20
#           reshape_width : 10
#             kernel_size : 9
#             in_channels : 9
#                     way : parallel
#            first_atrous : 1
#           second_atrous : 2
#            third_atrous : 2
#               acre_bias : True
#              model_name : DistMult
#                   debug : False
#                     exp : False
#            dataset_name : UMLS_KG
#            dataset_path : /home/ubuntu/Desktop/covid-project/UMLS_KG
#          load_from_data : None
#              save_model : True
#                test_num : 1000
#               test_step : 10
#                     tmp : ../intermediate
#                  result : ../results
#                 figures : ../figures
#          plot_embedding : False
#        plot_entity_only : False
#                  device : cpu
#         num_process_gen : 2
#             hp_abs_file : None
#             ss_abs_file : None
#       max_number_trials : 100
#                    hits : [1, 3, 5, 10]
#             disp_result : False
#                patience : 3
#         disp_triple_num : 20
#    plot_training_result : True
#     plot_testing_result : True
#              tot_triple : 6
#       tot_valid_triples : 1
#        tot_test_triples : 1
#       tot_train_triples : 4
#            tot_relation : 4
#              tot_entity : 7
#                path_tmp : /home/ubuntu/Desktop/covid-project/UMLS_KG/intermediate
#             path_result : /home/ubuntu/Desktop/covid-project/UMLS_KG/results
#            path_figures : /home/ubuntu/Desktop/covid-project/UMLS_KG/figures
#         path_embeddings : /home/ubuntu/Desktop/covid-project/UMLS_KG/embeddings
# ---------------------------------------------------
#
# 2021-05-24 20:50:51,909 - pykg2vec.utils.trainer - INFO - Epoch[0/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,912 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 20.45it/s]
# 2021-05-24 20:50:51,963 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 0 --- time: 0.05------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:51,976 - pykg2vec.utils.trainer - INFO - Epoch[1/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,977 - pykg2vec.utils.trainer - INFO - Epoch[2/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,978 - pykg2vec.utils.trainer - INFO - Epoch[3/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,979 - pykg2vec.utils.trainer - INFO - Epoch[4/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,979 - pykg2vec.utils.trainer - INFO - Epoch[5/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,980 - pykg2vec.utils.trainer - INFO - Epoch[6/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,981 - pykg2vec.utils.trainer - INFO - Epoch[7/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,981 - pykg2vec.utils.trainer - INFO - Epoch[8/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,982 - pykg2vec.utils.trainer - INFO - Epoch[9/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,983 - pykg2vec.utils.trainer - INFO - Epoch[10/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,983 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 854.41it/s]
# 2021-05-24 20:50:51,986 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 10 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:51,986 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:51,986 - pykg2vec.utils.trainer - INFO - Epoch[11/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,987 - pykg2vec.utils.trainer - INFO - Epoch[12/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,988 - pykg2vec.utils.trainer - INFO - Epoch[13/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,988 - pykg2vec.utils.trainer - INFO - Epoch[14/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,989 - pykg2vec.utils.trainer - INFO - Epoch[15/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,989 - pykg2vec.utils.trainer - INFO - Epoch[16/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,990 - pykg2vec.utils.trainer - INFO - Epoch[17/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,990 - pykg2vec.utils.trainer - INFO - Epoch[18/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,991 - pykg2vec.utils.trainer - INFO - Epoch[19/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,991 - pykg2vec.utils.trainer - INFO - Epoch[20/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,992 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1384.72it/s]
# 2021-05-24 20:50:51,993 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 20 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:51,993 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:51,993 - pykg2vec.utils.trainer - INFO - Epoch[21/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,994 - pykg2vec.utils.trainer - INFO - Epoch[22/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,995 - pykg2vec.utils.trainer - INFO - Epoch[23/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,995 - pykg2vec.utils.trainer - INFO - Epoch[24/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,996 - pykg2vec.utils.trainer - INFO - Epoch[25/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,996 - pykg2vec.utils.trainer - INFO - Epoch[26/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,997 - pykg2vec.utils.trainer - INFO - Epoch[27/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,998 - pykg2vec.utils.trainer - INFO - Epoch[28/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,998 - pykg2vec.utils.trainer - INFO - Epoch[29/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,999 - pykg2vec.utils.trainer - INFO - Epoch[30/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:51,999 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1403.25it/s]
# 2021-05-24 20:50:52,001 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 30 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,001 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,001 - pykg2vec.utils.trainer - INFO - Epoch[31/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,002 - pykg2vec.utils.trainer - INFO - Epoch[32/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,002 - pykg2vec.utils.trainer - INFO - Epoch[33/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,003 - pykg2vec.utils.trainer - INFO - Epoch[34/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,003 - pykg2vec.utils.trainer - INFO - Epoch[35/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,004 - pykg2vec.utils.trainer - INFO - Epoch[36/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,005 - pykg2vec.utils.trainer - INFO - Epoch[37/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,005 - pykg2vec.utils.trainer - INFO - Epoch[38/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,006 - pykg2vec.utils.trainer - INFO - Epoch[39/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,006 - pykg2vec.utils.trainer - INFO - Epoch[40/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,007 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1232.53it/s]
# 2021-05-24 20:50:52,009 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 40 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,009 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,009 - pykg2vec.utils.trainer - INFO - Epoch[41/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,010 - pykg2vec.utils.trainer - INFO - Epoch[42/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,010 - pykg2vec.utils.trainer - INFO - Epoch[43/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,011 - pykg2vec.utils.trainer - INFO - Epoch[44/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,011 - pykg2vec.utils.trainer - INFO - Epoch[45/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,012 - pykg2vec.utils.trainer - INFO - Epoch[46/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,012 - pykg2vec.utils.trainer - INFO - Epoch[47/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,013 - pykg2vec.utils.trainer - INFO - Epoch[48/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,013 - pykg2vec.utils.trainer - INFO - Epoch[49/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,014 - pykg2vec.utils.trainer - INFO - Epoch[50/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,015 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 843.42it/s]
# 2021-05-24 20:50:52,017 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 50 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,017 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,017 - pykg2vec.utils.trainer - INFO - Epoch[51/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,019 - pykg2vec.utils.trainer - INFO - Epoch[52/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,020 - pykg2vec.utils.trainer - INFO - Epoch[53/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,020 - pykg2vec.utils.trainer - INFO - Epoch[54/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,021 - pykg2vec.utils.trainer - INFO - Epoch[55/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,021 - pykg2vec.utils.trainer - INFO - Epoch[56/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,022 - pykg2vec.utils.trainer - INFO - Epoch[57/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,022 - pykg2vec.utils.trainer - INFO - Epoch[58/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,023 - pykg2vec.utils.trainer - INFO - Epoch[59/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,024 - pykg2vec.utils.trainer - INFO - Epoch[60/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,024 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 859.66it/s]
# 2021-05-24 20:50:52,027 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 60 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,027 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,027 - pykg2vec.utils.trainer - INFO - Epoch[61/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,028 - pykg2vec.utils.trainer - INFO - Epoch[62/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,029 - pykg2vec.utils.trainer - INFO - Epoch[63/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,030 - pykg2vec.utils.trainer - INFO - Epoch[64/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,030 - pykg2vec.utils.trainer - INFO - Epoch[65/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,031 - pykg2vec.utils.trainer - INFO - Epoch[66/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,031 - pykg2vec.utils.trainer - INFO - Epoch[67/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,032 - pykg2vec.utils.trainer - INFO - Epoch[68/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,033 - pykg2vec.utils.trainer - INFO - Epoch[69/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,033 - pykg2vec.utils.trainer - INFO - Epoch[70/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,034 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1569.72it/s]
# 2021-05-24 20:50:52,035 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 70 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,036 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,036 - pykg2vec.utils.trainer - INFO - Epoch[71/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,036 - pykg2vec.utils.trainer - INFO - Epoch[72/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,037 - pykg2vec.utils.trainer - INFO - Epoch[73/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,037 - pykg2vec.utils.trainer - INFO - Epoch[74/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,038 - pykg2vec.utils.trainer - INFO - Epoch[75/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,038 - pykg2vec.utils.trainer - INFO - Epoch[76/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,039 - pykg2vec.utils.trainer - INFO - Epoch[77/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,039 - pykg2vec.utils.trainer - INFO - Epoch[78/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,040 - pykg2vec.utils.trainer - INFO - Epoch[79/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,040 - pykg2vec.utils.trainer - INFO - Epoch[80/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,041 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1472.72it/s]
# 2021-05-24 20:50:52,042 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 80 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,042 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,042 - pykg2vec.utils.trainer - INFO - Epoch[81/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,043 - pykg2vec.utils.trainer - INFO - Epoch[82/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,044 - pykg2vec.utils.trainer - INFO - Epoch[83/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,044 - pykg2vec.utils.trainer - INFO - Epoch[84/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,045 - pykg2vec.utils.trainer - INFO - Epoch[85/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,046 - pykg2vec.utils.trainer - INFO - Epoch[86/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,046 - pykg2vec.utils.trainer - INFO - Epoch[87/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,047 - pykg2vec.utils.trainer - INFO - Epoch[88/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,048 - pykg2vec.utils.trainer - INFO - Epoch[89/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,048 - pykg2vec.utils.trainer - INFO - Epoch[90/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,049 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1082.40it/s]
# 2021-05-24 20:50:52,051 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 90 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,051 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,052 - pykg2vec.utils.trainer - INFO - Epoch[91/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,052 - pykg2vec.utils.trainer - INFO - Epoch[92/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,053 - pykg2vec.utils.trainer - INFO - Epoch[93/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,053 - pykg2vec.utils.trainer - INFO - Epoch[94/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,054 - pykg2vec.utils.trainer - INFO - Epoch[95/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,055 - pykg2vec.utils.trainer - INFO - Epoch[96/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,055 - pykg2vec.utils.trainer - INFO - Epoch[97/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,056 - pykg2vec.utils.trainer - INFO - Epoch[98/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,057 - pykg2vec.utils.trainer - INFO - Epoch[99/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,059 - pykg2vec.utils.trainer - INFO - Epoch[100/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,060 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1077.40it/s]
# 2021-05-24 20:50:52,062 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 100 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,062 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,062 - pykg2vec.utils.trainer - INFO - Epoch[101/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,063 - pykg2vec.utils.trainer - INFO - Epoch[102/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,063 - pykg2vec.utils.trainer - INFO - Epoch[103/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,063 - pykg2vec.utils.trainer - INFO - Epoch[104/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,064 - pykg2vec.utils.trainer - INFO - Epoch[105/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,065 - pykg2vec.utils.trainer - INFO - Epoch[106/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,065 - pykg2vec.utils.trainer - INFO - Epoch[107/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,068 - pykg2vec.utils.trainer - INFO - Epoch[108/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,069 - pykg2vec.utils.trainer - INFO - Epoch[109/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,070 - pykg2vec.utils.trainer - INFO - Epoch[110/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,071 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 261.44it/s]
# 2021-05-24 20:50:52,078 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 110 --- time: 0.01------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,078 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,078 - pykg2vec.utils.trainer - INFO - Epoch[111/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,083 - pykg2vec.utils.trainer - INFO - Epoch[112/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,090 - pykg2vec.utils.trainer - INFO - Epoch[113/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,090 - pykg2vec.utils.trainer - INFO - Epoch[114/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,091 - pykg2vec.utils.trainer - INFO - Epoch[115/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,092 - pykg2vec.utils.trainer - INFO - Epoch[116/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,092 - pykg2vec.utils.trainer - INFO - Epoch[117/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,093 - pykg2vec.utils.trainer - INFO - Epoch[118/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,093 - pykg2vec.utils.trainer - INFO - Epoch[119/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,094 - pykg2vec.utils.trainer - INFO - Epoch[120/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,095 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1442.33it/s]
# 2021-05-24 20:50:52,096 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 120 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,096 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,096 - pykg2vec.utils.trainer - INFO - Epoch[121/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,097 - pykg2vec.utils.trainer - INFO - Epoch[122/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,098 - pykg2vec.utils.trainer - INFO - Epoch[123/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,099 - pykg2vec.utils.trainer - INFO - Epoch[124/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,105 - pykg2vec.utils.trainer - INFO - Epoch[125/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,106 - pykg2vec.utils.trainer - INFO - Epoch[126/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,107 - pykg2vec.utils.trainer - INFO - Epoch[127/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,108 - pykg2vec.utils.trainer - INFO - Epoch[128/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,108 - pykg2vec.utils.trainer - INFO - Epoch[129/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,109 - pykg2vec.utils.trainer - INFO - Epoch[130/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,110 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1258.42it/s]
# 2021-05-24 20:50:52,112 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 130 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,112 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,112 - pykg2vec.utils.trainer - INFO - Epoch[131/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,113 - pykg2vec.utils.trainer - INFO - Epoch[132/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,113 - pykg2vec.utils.trainer - INFO - Epoch[133/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,115 - pykg2vec.utils.trainer - INFO - Epoch[134/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,115 - pykg2vec.utils.trainer - INFO - Epoch[135/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,116 - pykg2vec.utils.trainer - INFO - Epoch[136/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,117 - pykg2vec.utils.trainer - INFO - Epoch[137/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,121 - pykg2vec.utils.trainer - INFO - Epoch[138/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,121 - pykg2vec.utils.trainer - INFO - Epoch[139/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,122 - pykg2vec.utils.trainer - INFO - Epoch[140/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,123 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 224.05it/s]
# 2021-05-24 20:50:52,129 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 140 --- time: 0.01------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,129 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,130 - pykg2vec.utils.trainer - INFO - Epoch[141/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,131 - pykg2vec.utils.trainer - INFO - Epoch[142/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,132 - pykg2vec.utils.trainer - INFO - Epoch[143/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,132 - pykg2vec.utils.trainer - INFO - Epoch[144/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,133 - pykg2vec.utils.trainer - INFO - Epoch[145/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,134 - pykg2vec.utils.trainer - INFO - Epoch[146/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,134 - pykg2vec.utils.trainer - INFO - Epoch[147/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,135 - pykg2vec.utils.trainer - INFO - Epoch[148/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,136 - pykg2vec.utils.trainer - INFO - Epoch[149/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,137 - pykg2vec.utils.trainer - INFO - Epoch[150/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,138 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1177.18it/s]
# 2021-05-24 20:50:52,140 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 150 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,140 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,141 - pykg2vec.utils.trainer - INFO - Epoch[151/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,141 - pykg2vec.utils.trainer - INFO - Epoch[152/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,142 - pykg2vec.utils.trainer - INFO - Epoch[153/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,142 - pykg2vec.utils.trainer - INFO - Epoch[154/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,143 - pykg2vec.utils.trainer - INFO - Epoch[155/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,144 - pykg2vec.utils.trainer - INFO - Epoch[156/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,144 - pykg2vec.utils.trainer - INFO - Epoch[157/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,145 - pykg2vec.utils.trainer - INFO - Epoch[158/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,146 - pykg2vec.utils.trainer - INFO - Epoch[159/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,147 - pykg2vec.utils.trainer - INFO - Epoch[160/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,148 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 999.83it/s]
# 2021-05-24 20:50:52,150 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 160 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,150 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,150 - pykg2vec.utils.trainer - INFO - Epoch[161/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,152 - pykg2vec.utils.trainer - INFO - Epoch[162/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,155 - pykg2vec.utils.trainer - INFO - Epoch[163/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,156 - pykg2vec.utils.trainer - INFO - Epoch[164/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,158 - pykg2vec.utils.trainer - INFO - Epoch[165/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,159 - pykg2vec.utils.trainer - INFO - Epoch[166/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,159 - pykg2vec.utils.trainer - INFO - Epoch[167/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,160 - pykg2vec.utils.trainer - INFO - Epoch[168/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,160 - pykg2vec.utils.trainer - INFO - Epoch[169/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,161 - pykg2vec.utils.trainer - INFO - Epoch[170/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,161 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1588.15it/s]
# 2021-05-24 20:50:52,163 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 170 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,163 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,163 - pykg2vec.utils.trainer - INFO - Epoch[171/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,163 - pykg2vec.utils.trainer - INFO - Epoch[172/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,164 - pykg2vec.utils.trainer - INFO - Epoch[173/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,165 - pykg2vec.utils.trainer - INFO - Epoch[174/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,165 - pykg2vec.utils.trainer - INFO - Epoch[175/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,166 - pykg2vec.utils.trainer - INFO - Epoch[176/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,167 - pykg2vec.utils.trainer - INFO - Epoch[177/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,167 - pykg2vec.utils.trainer - INFO - Epoch[178/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,168 - pykg2vec.utils.trainer - INFO - Epoch[179/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,169 - pykg2vec.utils.trainer - INFO - Epoch[180/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,169 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1475.83it/s]
# 2021-05-24 20:50:52,171 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 180 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,171 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,171 - pykg2vec.utils.trainer - INFO - Epoch[181/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,171 - pykg2vec.utils.trainer - INFO - Epoch[182/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,172 - pykg2vec.utils.trainer - INFO - Epoch[183/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,172 - pykg2vec.utils.trainer - INFO - Epoch[184/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,173 - pykg2vec.utils.trainer - INFO - Epoch[185/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,173 - pykg2vec.utils.trainer - INFO - Epoch[186/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,174 - pykg2vec.utils.trainer - INFO - Epoch[187/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,174 - pykg2vec.utils.trainer - INFO - Epoch[188/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,175 - pykg2vec.utils.trainer - INFO - Epoch[189/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,175 - pykg2vec.utils.trainer - INFO - Epoch[190/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,176 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 812.69it/s]
# 2021-05-24 20:50:52,178 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 190 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,178 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,178 - pykg2vec.utils.trainer - INFO - Epoch[191/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,179 - pykg2vec.utils.trainer - INFO - Epoch[192/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,180 - pykg2vec.utils.trainer - INFO - Epoch[193/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,181 - pykg2vec.utils.trainer - INFO - Epoch[194/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,182 - pykg2vec.utils.trainer - INFO - Epoch[195/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,182 - pykg2vec.utils.trainer - INFO - Epoch[196/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,183 - pykg2vec.utils.trainer - INFO - Epoch[197/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,184 - pykg2vec.utils.trainer - INFO - Epoch[198/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,185 - pykg2vec.utils.trainer - INFO - Epoch[199/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,185 - pykg2vec.utils.trainer - INFO - Epoch[200/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,186 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 652.51it/s]
# 2021-05-24 20:50:52,189 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 200 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,190 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,190 - pykg2vec.utils.trainer - INFO - Epoch[201/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,190 - pykg2vec.utils.trainer - INFO - Epoch[202/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,191 - pykg2vec.utils.trainer - INFO - Epoch[203/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,191 - pykg2vec.utils.trainer - INFO - Epoch[204/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,192 - pykg2vec.utils.trainer - INFO - Epoch[205/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,193 - pykg2vec.utils.trainer - INFO - Epoch[206/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,193 - pykg2vec.utils.trainer - INFO - Epoch[207/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,194 - pykg2vec.utils.trainer - INFO - Epoch[208/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,195 - pykg2vec.utils.trainer - INFO - Epoch[209/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,196 - pykg2vec.utils.trainer - INFO - Epoch[210/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,196 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 560.96it/s]
# 2021-05-24 20:50:52,200 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 210 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,200 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,200 - pykg2vec.utils.trainer - INFO - Epoch[211/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,201 - pykg2vec.utils.trainer - INFO - Epoch[212/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,202 - pykg2vec.utils.trainer - INFO - Epoch[213/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,202 - pykg2vec.utils.trainer - INFO - Epoch[214/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,203 - pykg2vec.utils.trainer - INFO - Epoch[215/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,203 - pykg2vec.utils.trainer - INFO - Epoch[216/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,204 - pykg2vec.utils.trainer - INFO - Epoch[217/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,204 - pykg2vec.utils.trainer - INFO - Epoch[218/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,205 - pykg2vec.utils.trainer - INFO - Epoch[219/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,206 - pykg2vec.utils.trainer - INFO - Epoch[220/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,206 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 844.77it/s]
# 2021-05-24 20:50:52,209 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 220 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,209 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,209 - pykg2vec.utils.trainer - INFO - Epoch[221/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,210 - pykg2vec.utils.trainer - INFO - Epoch[222/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,211 - pykg2vec.utils.trainer - INFO - Epoch[223/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,212 - pykg2vec.utils.trainer - INFO - Epoch[224/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,213 - pykg2vec.utils.trainer - INFO - Epoch[225/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,214 - pykg2vec.utils.trainer - INFO - Epoch[226/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,214 - pykg2vec.utils.trainer - INFO - Epoch[227/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,215 - pykg2vec.utils.trainer - INFO - Epoch[228/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,215 - pykg2vec.utils.trainer - INFO - Epoch[229/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,216 - pykg2vec.utils.trainer - INFO - Epoch[230/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,216 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 989.92it/s]
# 2021-05-24 20:50:52,219 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 230 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,219 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,219 - pykg2vec.utils.trainer - INFO - Epoch[231/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,221 - pykg2vec.utils.trainer - INFO - Epoch[232/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,222 - pykg2vec.utils.trainer - INFO - Epoch[233/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,223 - pykg2vec.utils.trainer - INFO - Epoch[234/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,224 - pykg2vec.utils.trainer - INFO - Epoch[235/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,225 - pykg2vec.utils.trainer - INFO - Epoch[236/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,225 - pykg2vec.utils.trainer - INFO - Epoch[237/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,226 - pykg2vec.utils.trainer - INFO - Epoch[238/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,227 - pykg2vec.utils.trainer - INFO - Epoch[239/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,228 - pykg2vec.utils.trainer - INFO - Epoch[240/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,228 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 215.06it/s]
# 2021-05-24 20:50:52,234 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 240 --- time: 0.01------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,234 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# ...
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,847 - pykg2vec.utils.trainer - INFO - Epoch[918/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,847 - pykg2vec.utils.trainer - INFO - Epoch[919/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,849 - pykg2vec.utils.trainer - INFO - Epoch[920/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,850 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1128.71it/s]
# 2021-05-24 20:50:52,852 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 920 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,852 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,852 - pykg2vec.utils.trainer - INFO - Epoch[921/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,854 - pykg2vec.utils.trainer - INFO - Epoch[922/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,855 - pykg2vec.utils.trainer - INFO - Epoch[923/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,857 - pykg2vec.utils.trainer - INFO - Epoch[924/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,857 - pykg2vec.utils.trainer - INFO - Epoch[925/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,858 - pykg2vec.utils.trainer - INFO - Epoch[926/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,859 - pykg2vec.utils.trainer - INFO - Epoch[927/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,859 - pykg2vec.utils.trainer - INFO - Epoch[928/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,860 - pykg2vec.utils.trainer - INFO - Epoch[929/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,860 - pykg2vec.utils.trainer - INFO - Epoch[930/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,861 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1366.22it/s]
# 2021-05-24 20:50:52,863 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 930 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,863 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,863 - pykg2vec.utils.trainer - INFO - Epoch[931/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,863 - pykg2vec.utils.trainer - INFO - Epoch[932/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,864 - pykg2vec.utils.trainer - INFO - Epoch[933/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,865 - pykg2vec.utils.trainer - INFO - Epoch[934/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,866 - pykg2vec.utils.trainer - INFO - Epoch[935/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,866 - pykg2vec.utils.trainer - INFO - Epoch[936/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,867 - pykg2vec.utils.trainer - INFO - Epoch[937/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,867 - pykg2vec.utils.trainer - INFO - Epoch[938/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,868 - pykg2vec.utils.trainer - INFO - Epoch[939/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,869 - pykg2vec.utils.trainer - INFO - Epoch[940/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,870 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1188.19it/s]
# 2021-05-24 20:50:52,872 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 940 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,872 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,872 - pykg2vec.utils.trainer - INFO - Epoch[941/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,873 - pykg2vec.utils.trainer - INFO - Epoch[942/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,873 - pykg2vec.utils.trainer - INFO - Epoch[943/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,874 - pykg2vec.utils.trainer - INFO - Epoch[944/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,875 - pykg2vec.utils.trainer - INFO - Epoch[945/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,876 - pykg2vec.utils.trainer - INFO - Epoch[946/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,876 - pykg2vec.utils.trainer - INFO - Epoch[947/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,877 - pykg2vec.utils.trainer - INFO - Epoch[948/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,877 - pykg2vec.utils.trainer - INFO - Epoch[949/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,878 - pykg2vec.utils.trainer - INFO - Epoch[950/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,879 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 959.14it/s]
# 2021-05-24 20:50:52,881 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 950 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,882 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,882 - pykg2vec.utils.trainer - INFO - Epoch[951/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,882 - pykg2vec.utils.trainer - INFO - Epoch[952/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,883 - pykg2vec.utils.trainer - INFO - Epoch[953/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,884 - pykg2vec.utils.trainer - INFO - Epoch[954/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,884 - pykg2vec.utils.trainer - INFO - Epoch[955/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,885 - pykg2vec.utils.trainer - INFO - Epoch[956/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,886 - pykg2vec.utils.trainer - INFO - Epoch[957/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,887 - pykg2vec.utils.trainer - INFO - Epoch[958/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,887 - pykg2vec.utils.trainer - INFO - Epoch[959/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,890 - pykg2vec.utils.trainer - INFO - Epoch[960/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,890 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1521.33it/s]
# 2021-05-24 20:50:52,892 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 960 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,892 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,892 - pykg2vec.utils.trainer - INFO - Epoch[961/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,893 - pykg2vec.utils.trainer - INFO - Epoch[962/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,893 - pykg2vec.utils.trainer - INFO - Epoch[963/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,894 - pykg2vec.utils.trainer - INFO - Epoch[964/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,894 - pykg2vec.utils.trainer - INFO - Epoch[965/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,894 - pykg2vec.utils.trainer - INFO - Epoch[966/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,895 - pykg2vec.utils.trainer - INFO - Epoch[967/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,898 - pykg2vec.utils.trainer - INFO - Epoch[968/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,899 - pykg2vec.utils.trainer - INFO - Epoch[969/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,900 - pykg2vec.utils.trainer - INFO - Epoch[970/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,901 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1116.99it/s]
# 2021-05-24 20:50:52,903 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 970 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,904 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,904 - pykg2vec.utils.trainer - INFO - Epoch[971/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,904 - pykg2vec.utils.trainer - INFO - Epoch[972/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,905 - pykg2vec.utils.trainer - INFO - Epoch[973/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,906 - pykg2vec.utils.trainer - INFO - Epoch[974/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,906 - pykg2vec.utils.trainer - INFO - Epoch[975/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,907 - pykg2vec.utils.trainer - INFO - Epoch[976/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,908 - pykg2vec.utils.trainer - INFO - Epoch[977/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,909 - pykg2vec.utils.trainer - INFO - Epoch[978/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,909 - pykg2vec.utils.trainer - INFO - Epoch[979/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,910 - pykg2vec.utils.trainer - INFO - Epoch[980/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,911 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1170.94it/s]
# 2021-05-24 20:50:52,912 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 980 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,913 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,913 - pykg2vec.utils.trainer - INFO - Epoch[981/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,913 - pykg2vec.utils.trainer - INFO - Epoch[982/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,915 - pykg2vec.utils.trainer - INFO - Epoch[983/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,915 - pykg2vec.utils.trainer - INFO - Epoch[984/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,916 - pykg2vec.utils.trainer - INFO - Epoch[985/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,916 - pykg2vec.utils.trainer - INFO - Epoch[986/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,917 - pykg2vec.utils.trainer - INFO - Epoch[987/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,920 - pykg2vec.utils.trainer - INFO - Epoch[988/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,921 - pykg2vec.utils.trainer - INFO - Epoch[989/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,921 - pykg2vec.utils.trainer - INFO - Epoch[990/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,922 - pykg2vec.utils.evaluator - INFO - Mini-Testing on [1/1] Triples in the valid set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1393.92it/s]
# 2021-05-24 20:50:52,924 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 990 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 6.5000, 6.5000
# --mrr, filtered mrr            : 0.1548, 0.1548
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.0000
# --filtered hits5               : 0.0000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------
#
# 2021-05-24 20:50:52,924 - pykg2vec.utils.trainer - INFO - Reset the patience count to 3
# 2021-05-24 20:50:52,924 - pykg2vec.utils.trainer - INFO - Epoch[991/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,924 - pykg2vec.utils.trainer - INFO - Epoch[992/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,925 - pykg2vec.utils.trainer - INFO - Epoch[993/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,925 - pykg2vec.utils.trainer - INFO - Epoch[994/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,926 - pykg2vec.utils.trainer - INFO - Epoch[995/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,926 - pykg2vec.utils.trainer - INFO - Epoch[996/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,927 - pykg2vec.utils.trainer - INFO - Epoch[997/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,927 - pykg2vec.utils.trainer - INFO - Epoch[998/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,929 - pykg2vec.utils.trainer - INFO - Epoch[999/1000]
# 0it [00:00, ?it/s]
# 2021-05-24 20:50:52,929 - pykg2vec.utils.evaluator - INFO - Full-Testing on [1/1] Triples in the test set.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1028.52it/s]
# 2021-05-24 20:50:52,932 - pykg2vec.utils.evaluator - INFO -
# ------Test Results for UMLS_KG: Epoch: 999 --- time: 0.00------------
# --# of entities, # of relations: 7, 4
# --mr,  filtered mr             : 5.5000, 5.5000
# --mrr, filtered mrr            : 0.1833, 0.1833
# --hits1                        : 0.0000
# --filtered hits1               : 0.0000
# --hits3                        : 0.0000
# --filtered hits3               : 0.0000
# --hits5                        : 0.5000
# --filtered hits5               : 0.5000
# --hits10                        : 1.0000
# --filtered hits10               : 1.0000
# ---------------------------------------------------------

# %%
#Converting KGE to BERT embeddings (Domain Term Encoding (DTE)) - part1 (generating associated triples)
#[Entity Expansion]
# %cd ~/Desktop/covid-project/UMLS_KG/

import numpy as np
import pandas as pd
import pickle

#Mapping b/w entity and corresponding ID
with open('entity2idx.pkl', 'rb') as f:
    entity2id = pickle.load(f)

#Mapping b/w relation and corresponding ID
with open('relation2idx.pkl', 'rb') as f:
    relation2id = pickle.load(f)

def triple_gen(current_entity):
    results = KGT.query("E1==@current_entity")
    connected_entities = results.E2.to_list()
    outgoing_relations = results.Rel.to_list()
    a = []
    for i in range(len(results)):
        a.append([current_entity, outgoing_relations[i], connected_entities[i]])
    a = [y for x in a for y in x]
    return a

triple_list = []
for entity in tqdm(entity2id.keys()):
    triple_list.append(triple_gen(entity))
# Out:
# /home/ubuntu/Desktop/covid-project/UMLS_KG
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))

# %%
#Converting KGE to BERT embeddings (Domain Term Encoding (DTE)) - part2 (each KG item -> (KG item, KGE))
#KGE located here
# %cd ~/Desktop/covid-project/UMLS_KG/embeddings/distmult

ent_embeddings = pd.read_csv('ent_embedding.tsv', sep='\t', header=None)
rel_embeddings = pd.read_csv('rel_embedding.tsv', sep='\t', header=None)

'''
Associating each item in the triple list with respective embeddings. 
This is done to create an easy Domain Term BERT embedding matrix.
'''
for TL in tqdm(triple_list):
    if TL == []:
        continue
    i = 0
    for index, item in enumerate(TL):
        if (i%3 == 0) or (i%3 == 2): #This item is an entity
            TL[index] = (item, ent_embeddings.iloc[entity2id[item]].to_numpy())
        else: #This item is a relation
            TL[index] = (item, rel_embeddings.iloc[relation2id[item]].to_numpy())
        i += 1
# Out:
# /home/ubuntu/Desktop/covid-project/UMLS_KG/embeddings/distmult
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))

# %%
#Converting KGE to BERT embeddings (Domain Term Encoding (DTE)) - part3 (Passing KGE's through BERT) 
#[Creating DTE Lookup Table]
from transformers import BertModel
import torch

model = BertModel.from_pretrained('bert-base-uncased')
model.eval()

matrix = model.get_input_embeddings() #BERT embeddings

CLS_embedding = matrix(torch.LongTensor([101]))
SEP_embedding = matrix(torch.LongTensor([102]))

DTE_BERT_Matrix = {}

with torch.no_grad():
    for seq in tqdm(triple_list):
        if seq == []:
            continue
        
        outputs = model(inputs_embeds = torch.unsqueeze(\
                                        torch.cat(\
                                        (CLS_embedding,\
                                         torch.FloatTensor([x[1] for x in seq]), SEP_embedding)), dim=1))
        
        #Collecting all the embeddings for the current domain term in e[]
        e = []
        
        '''
        Starting at 1 & ending at (len -1) to a/c for [CLS] & [SEP].
        Step size is 3 since the required entity occurs in spaces of 3, according to the expansion scheme.
        '''
        for i in range(1, (len(seq) - 1), 3): 
            e.append(outputs[0][i])
        
        '''
        The BERT embedding for each entity will be the average of all its occurrences.
        *e provides all the elements of e (unpacking).
        '''
        DTE_BERT_Matrix[seq[0][0]] = torch.mean(torch.stack([*e], dim=0), dim=0)

'''
Saving DTE_BERT embeddings to a lookup table (dataframe) & clearing DTE_BERT_Matrix.
Dataframes allow quicker lookups
'''
s = pd.DataFrame(list(DTE_BERT_Matrix.items()),columns = ['Term','Embedding'])
s.to_csv('DTE_BERT_Matrix.csv')
DTE_BERT_Matrix.clear()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))

# %%
#Extracting embeddings for non-domain terms. I'm simply using BERT's tokenizer for the nDT's.
#Creating question representations in this block.
from transformers import BertTokenizer, BertModel
import torch
import re

#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
question_representations = []

for tup in Metamap_Tokenizations:
    metamap_tokenized_question = tup[1]
    
    #Removing punctuations/spaces from domain-terms for easy comparison
    domain_terms = [re.sub(r'[\W\s]','',x[0]).lower() for x in tup[2]] 

    '''
    Note: is_split_into_words is not the same as pre-tokenized. BERT uses subwords tokenization.
    Thus, when the above is set to True, it simply tells the tokenizer to run BERT's scheme on the resp. words.
    '''
    encoded_input = tokenizer(metamap_tokenized_question, is_split_into_words=True, return_tensors="pt")
    
    model.eval()
    with torch.no_grad():
        outputs = model(**encoded_input)
    
    question_embeddings = []
    start_index = 1
    for word in metamap_tokenized_question:
        filtered_word = re.sub(r'\W','',word).lower()
        number_of_subwords = len(tokenizer(word)['input_ids']) - 2 #1 for CLS & 1 for SEP
        end_index = start_index + number_of_subwords
        
        if filtered_word in domain_terms: #Use DTE_BERT_Matrix
            mapped_concept = tup[2][domain_terms.index(filtered_word)][1]
            DTE = s.query("Term==@mapped_concept")['Embedding'].values[0]
            question_embeddings.append(DTE)
        
        else: #Use Regular BERT subword embeddings
            question_embeddings.append(outputs.last_hidden_state[0][start_index:end_index])
        
        start_index = end_index
    
    #In this way, I don't have to add the CLS & SEP embeddings during fine-tuning.
    final_representation = torch.unsqueeze(torch.cat(\
                                                     (CLS_embedding, \
                                                      torch.FloatTensor([x for x in question_embeddings]),\
                                                      SEP_embedding)), dim=1)
    
    question_representations.append(final_representation)

#Saving the question vectors to disk
with open('question_representation.data', 'wb') as filehandle:
    pickle.dump(question_representations, filehandle)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-278-163428a75f4c> in <module>
#      33         if filtered_word in domain_terms: #Use DTE_BERT_Matrix
#      34             mapped_concept = tup[2][domain_terms.index(filtered_word)][1]
# ---> 35             DTE = s.query("Term==@mapped_concept")['Embedding'].values[0]
#      36             question_embeddings.append(DTE)
#      37
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
entity2id
# Out:
# {'Daily or Recreational Activity': 0,
#  'Disease or Syndrome': 1,
#  'Functional Concept': 2,
#  'Idea or Concept': 3,
#  'Pathologic Function': 4,
#  'Qualitative Concept': 5,
#  'Virus': 6}
